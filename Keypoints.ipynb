# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport keypoints
# %aimport plots
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
(X, Y) = keypoints.df_train()

# %%
plots.show_img(X, Y, 0)

# %%
model = keypoints.train(X,Y)

# %%
(ids, X) = keypoints.df_test(); predict = model.predict(X)

# %%
index=4
imgplot = plt.imshow(X.iloc[index].reshape(96, 96), cmap=plt.cm.gray)
plt.plot((predict[index], predict[index]), (0, 96))

# %%
predict
# Out:
# array([ 63.99175363,  69.89911781,  64.49586366, ...,  67.84928811,
#         67.54289925,  66.51994172])

# %%
(model.coef_ + 10).reshape(96, 96)
# Out:
# array([[  9.99955369,   9.99868812,   9.9989396 , ...,   9.99790448,
#          10.00106851,  10.00040347],
#        [  9.99945942,   9.99925814,  10.00073374, ...,  10.00025991,
#          10.00075349,  10.00063863],
#        [ 10.00086887,  10.00048926,  10.00030971, ...,   9.99937411,
#           9.99975137,   9.99910972],
#        ...,
#        [  9.99902449,  10.00174346,  10.00124087, ...,   9.99891451,
#          10.00070516,  10.00108209],
#        [ 10.00038598,  10.00176734,   9.99988704, ...,   9.9992494 ,
#           9.99964537,  10.00026869],
#        [  9.99740714,  10.0001723 ,  10.00056574, ...,  10.00021186,
#           9.99978502,   9.99977759]])

# %%
plt.imshow((model.coef_ + 20).reshape(96, 96), cmap=plt.cm.gray)
